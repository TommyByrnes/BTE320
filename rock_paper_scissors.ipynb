# %% [markdown]
# <a href="https://colab.research.google.com/github/TommyByrnes/BTE320/blob/main/rock_paper_scissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

play = input("Do you want to play Rock-Paper-Scissors? (yes/no): ").lower()

while play == "yes":

    user_move = input("Choose rock, paper, or scissors: ").lower()


    computer_move = random.choice(["rock", "paper", "scissors"])

    print("Computer chose:", computer_move)

    if user_move == computer_move:
        print("It's a tie!")

    elif (user_move == "rock" and computer_move == "scissors") or \
         (user_move == "paper" and computer_move == "rock") or \
         (user_move == "scissors" and computer_move == "paper"):
        print("You win!")

    elif user_move in ["rock", "paper", "scissors"]:
        print("Computer wins!")

    else:
        print("Invalid choice.")

    play = input("Do you want to play again? (yes/no): ").lower()

print("Thanks for playing!")
# Out:
# Do you want to play Rock-Paper-Scissors? (yes/no): yes
# Choose rock, paper, or scissors: rock
# Computer chose: rock
# It's a tie!
# Do you want to play again? (yes/no): yes
# Choose rock, paper, or scissors: rock
# Computer chose: scissors
# You win!
# Do you want to play again? (yes/no): no
# Thanks for playing!
