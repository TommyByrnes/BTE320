# %% [markdown]
# <a href="https://colab.research.google.com/github/TommyByrnes/BTE320/blob/main/InventoryManagement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

D = float(input("Enter annual demand (units/year): "))
S = float(input("Enter ordering cost ($/order): "))
H = float(input("Enter holding cost ($/year/unit): "))

EOQ = math.sqrt((2 * D * S) / H)
print(f"EOQ: {EOQ:.2f} units")
