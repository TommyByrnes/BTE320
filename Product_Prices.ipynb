# %% [markdown]
# <a href="https://colab.research.google.com/github/TommyByrnes/BTE320/blob/main/Product_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
products = {"P-01": 9.95, "P-02": 10.50}

product_id = input("Enter product ID: ")

if product_id in products:
    print(product_id, products[product_id])
else:
    print(product_id, "not found")
# Out:
# Enter product ID: P-01
# P-01 9.95
