# %% [markdown]
# <a href="https://colab.research.google.com/github/TommyByrnes/BTE320/blob/main/ParkingGrageCalcFee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calcFee(hours):
    return 5 + 2.50 * hours

def main():
    hours = float(input("Enter hours parked: "))
    fee = calcFee(hours)
    print(f"Fee: ${fee}")

main()
