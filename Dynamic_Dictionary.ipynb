# %% [markdown]
# <a href="https://colab.research.google.com/github/TommyByrnes/BTE320/blob/main/Dynamic_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 5
counts = {}

for i in range(N):
    name = input(f"Enter name ({i+1}/{N}): ")
    if name in counts:
        counts[name] += 1
    else:
        counts[name] = 1

print("Final dictionary:", counts)
