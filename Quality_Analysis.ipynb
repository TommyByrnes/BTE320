# %% [markdown]
# <a href="https://colab.research.google.com/github/TommyByrnes/BTE320/blob/main/Quality_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
weights = [10.0, 9.9, 10.1, 10.05]

average = sum(weights) / len(weights)
largest = max(weights)

print("Average=", average)
print("Largest=", largest)
# Out:
# Average= 10.0125
# Largest= 10.1
